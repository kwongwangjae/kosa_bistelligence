# %%
result = 10**4
print(result)
# Out:
# 10000

# %%
result = 10 // 4
print(result)

result = 10 % 4
print(result)
# Out:
# 2
# 2

# %%
result = 10
result **= 5
print(result)
# Out:
# 100000

# %%
var1 = 100
var2 = 100
print(var1 == var2) # 이게 값비교임
print("var1 번지:" , id(var1))
print("var2 번지:" , id(var2))

print(var1 is var2) # 번지 비교
# Out:
# True
# var1 번지: 4376931104
# var2 번지: 4376931104
# True
