# %%
# 타입 힌트
name: str = "홍길동"
print(name)
# Out:
# 홍길동

# %%
from typing import Any

age : int = 30
height = float = 175.5
is_active = bool = True

value: Any = "홍길동"
value: Any = 10
value: Any = True

# %%
name1: str = None # 필수 값
name2: str | None = None # 옵션 값
