# %%
grade= ( 1, 2, 3, 4, 5 )
season = ( "봄", "여름", "가을", "겨울" )
day = ( "월", "화", "수", "목", "금", "토" )

print(grade, f"요소수: {len(grade)}")
print(season, f"요소수: {len(season)}")
print(day, f"요소수: {len(day)}")
# Out:
# (1, 2, 3, 4, 5) 요소수: 5
# ('봄', '여름', '가을', '겨울') 요소수: 4
# ('월', '화', '수', '목', '금', '토') 요소수: 6

# %%
grade: tuple = ( 1, 2, 3, 4, 5 )
season = ( "봄", "여름", "가을", "겨울" )
day = ( "월", "화", "수", "목", "금", "토" )

print(grade, f"요소수: {len(grade)}")
print(season, f"요소수: {len(season)}")
print(day, f"요소수: {len(day)}")

# %%
names = ["홍길동", "홍삼원", "홍길남"]

for index, value in enumerate(names):
    print(index, value)

for name in enumerate(names):
    print(name)
# Out:
# 0 홍길동
# 1 홍삼원
# 2 홍길남
# (0, '홍길동')
# (1, '홍삼원')
# (2, '홍길남')
