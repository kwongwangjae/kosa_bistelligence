# %%
member: dict[str, any] = { 
    "id":"python",
    "name":"파이썬",
    "age":20,
    "tel":"0101231234" 
}

name = member["name"]
print(name)

# %%
member = {
    "name": "홍길동",
    "grade": 3,
    "adult": False,
    "hobby": ["영화", "축구"],
    "school": ("대치초등학교", "서초중학교", "강남고등학교"),
    "family": {"father": "홍삼원", "mother": "김순희"}
}

middle_school = member.get("school")[1]
print(middle_school)

mother_name = member.get("family").get("mother")
print(mother_name)
# Out:
# 서초중학교
# 김순희
