# %%
board: list[dict] = []

# %%
from datetime import datetime

def add_board(
    title: str,
    content: str,
    writer: datetime = datetime.now(),
    date: int = 0,
    hitcount: str
    )-> None:
    board: dict = {
        "title": title,
        "content": content,
        "writer": writer,
        "date": date,
        "hintcount": hitcount
    } 
    
    boards.append(board)
