# %%
def fun1(param: int) -> None:
    param = 10

def fun2(param: list) -> None:
    param[0] = 10


# immutable: Call By Value
var1 = 5
fun1(var1)
print("var1:", var1)

var2 = [1,2,3]
fun2(var2)
print(var2)
# Out:
# var1: 5
