# %%
list()
tuple()
dict()

# 객체 생성 코드 
# 생성자 호출
cities = list()
season = tuple(["봄", "여름", "가을", "겨울"]) # season = ("봄", "여름", "가을", "겨울")
member = dict() # member = {}

# %%
def add(x ,y):
    return x + y

add = lambda x, y: x + y

print(add(3, 5))
