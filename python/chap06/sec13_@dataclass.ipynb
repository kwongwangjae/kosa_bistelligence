# %%
from dataclasses import dataclass

@dataclass
class Member:
    mid: str
    mname: str
    mage: int

m1 = Member("user1", "홍길동", 30)
print(m1)

m2 = Member("user1", "홍길동", 30)
print(m2)

print(m1 == m2)
print(m1 is m2)
