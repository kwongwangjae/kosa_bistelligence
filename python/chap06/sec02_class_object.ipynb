# %%
class Car:
    pass

# %%
car1 = Car() # __new__() --> __init__()
car2 = Car()

print(id(car1))
print(id(car2))
# Out:
# 4468065440
# 4468065392

# %%
#  __ 이런 식은 매직 메서드 라고 명칭
# __new__() : 생성자의 역할을 함 / 클래스 메서드 -> java 정적 메서드
