# %%
import mypack.module1
import mypack.module2
import mypack.module3

mypack.module1.fun()
mypack.module2.fun()
mypack.module3.fun()
# Out:
# mypack/module1.py의 fun() 실행
# mypack/module2.py의 fun() 실행
# mypack/module3.py의 fun() 실행

# %%
from mypack import module1, module2, module3

module1.fun()
module2.fun()
module3.fun()
# Out:
# mypack/module1.py의 fun() 실행
# mypack/module2.py의 fun() 실행
# mypack/module3.py의 fun() 실행

# %%
# 모듈로 부터는 모든 정의된 멤버(변수, 함수, 클래스)를 *로 가져올 수 있음
from mypack import fun
fun()
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[4], line 2
#       1 # 모듈로 부터는 모든 정의된 멤버(변수, 함수, 클래스)를 *로 가져올 수 있음
# ----> 2 from mypack import fun
#       3 fun()
#       4
#
# ImportError: cannot import name 'fun' from 'mypack' (unknown location)

# %%
fun mypaack.subpack import module4
module4.fun()

# %%
from mypack.subpack.module4 import fun
fun()
